# %%
import balltracking.balltrack as blt
import os, glob
import fitsio
from scipy.ndimage.filters import gaussian_filter 
from scipy.signal import convolve2d
from scipy.io import readsav
import numpy as np
import matplotlib
#matplotlib.use('tkagg')
import matplotlib.pyplot as plt
from matplotlib import rc
# Load FLCT
from pathlib import Path, PurePath
from IPython.display import display
import time
import pandas as pd


matplotlib.rcParams.update({'font.size': 12})
matplotlib.rcParams.update({'xtick.labelsize': 12, 'ytick.labelsize': 12})
matplotlib.rcParams.update({'axes.labelsize': 12})

# %%
def load_vel_mean(v_files, trange):
    "Load the velocity files and average over a time range"
    vxs = []
    vys = []
    vx_files_subset = v_files[0][trange[0]:trange[1]]
    vy_files_subset = v_files[1][trange[0]:trange[1]]
    for vxf, vyf in zip(vx_files_subset, vy_files_subset):
        vxs.append(fitsio.read(vxf))
        vys.append(fitsio.read(vyf))
    # Get the mean of the velocity components
    vx = np.array(vxs).mean(axis=0)
    vy = np.array(vys).mean(axis=0)
    return np.array([vx, vy])


def smooth_vel(v, fwhm, kernel='boxcar'):
    """ Smooth the velocity with a smoothing kernel that can either be: 
     - boxcar: width set to fwhm
     - gaussian: parametrized by fwhm. 
     
     Returns the smoothed velocity components
    """ 
    
    if kernel == 'boxcar':
        box = np.ones([fwhm, fwhm]) / fwhm**2
        vxs2 = convolve2d(v[0,...], box, mode='same')
        vys2 = convolve2d(v[1,...], box, mode='same')
    elif kernel == 'gaussian':
        sigma = fwhm / 2.35
        vxs2 = gaussian_filter(v[0,...], sigma=sigma, order=0)
        vys2 = gaussian_filter(v[1,...], sigma=sigma, order=0)
        
    vm = np.sqrt(vxs2**2 + vys2**2)
    return np.array([vxs2, vys2, vm])


# For FLCT
def read_vi(file, data_str):
    idl_dict = readsav(file)
    vi = idl_dict[data_str]
    return vi


def calc_c_pearson(vx1, vx2, vy1, vy2, fov=None):
    vx1f, vx2f, vy1f, vy2f = vx1[fov], vx2[fov], vy1[fov], vy2[fov]
    c_pearson = np.sum(vx1f*vx2f + vy1f*vy2f) / np.sqrt(np.sum(vx1f**2 + vy1f**2)*np.sum(vx2f**2 + vy2f**2))
    return c_pearson

# %%
datadir = os.path.join(os.environ['DATA'], 'Ben/SteinSDO')
outputdir = os.path.join(datadir, 'comparisons')

u = 368000 / 60

fwhms = [7,9,11,13,15]
kernels = ['boxcar', 'gaussian']
fwhm = 7
kernel = 'boxcar'
dims = [263, 263]
# Select a subfield excluding edge effects
# Use same padding size as in Tremblay et al. 2018 used pad = 10
pad = 10
step = fwhm
fov = np.s_[pad:-pad:step, pad:-pad:step]

nframes = range(30, 365, 5)
tranges = [[0, nt] for nt in range(30, 365, 5)]
nflows = len(tranges)
print("number of time-averaged flow maps: ", nflows)
# Out:
# number of time-averaged flow maps:  67

# %% [markdown]
# ### Load Stein simulation data

# %%
# Load Stein data
svx_files = sorted(glob.glob(os.path.join(datadir,'SDO_vx*.fits')))
svy_files = sorted(glob.glob(os.path.join(datadir,'SDO_vy*.fits')))
#vx, vy = load_vel_mean((svx_files, svy_files), tranges[0])
v_stein_l = [load_vel_mean((svx_files, svy_files), trange) for trange in tranges]
# smooth the Stein velocities 
v_stein_sm = [[smooth_vel(v, fwhm, kernel=kernel) for v in v_stein_l] for fwhm in fwhms]
npts = v_stein_sm[0][0][0][fov].size

# %% [markdown]
# ### Balltracking data

# %%
dfs1 = []
dfs2 = []

for i, fwhm_i in enumerate(fwhms):
    # Load Balltrack velocities (processed with balltracking_scripts/generic_balltrack.py)
    bvs = [np.array([np.load(os.path.join(datadir, 'balltrack/vxy_{:s}_fwhm_{:d}_avg_{:d}.npz'.format(kernel, fwhm_i, trange[1])))[var] for var in ['vx', 'vy']]) for trange in tranges]
    bvsm = [np.sqrt(bvs[j][0][:]**2 + bvs[j][1][:]**2) for j in range(nflows)]
    
    # Fit Balltracking to Stein simulation
    bps, brs, _, _, _ = zip(*[np.polyfit(bvs[j][0][fov].ravel()*u, v_stein_sm[i][j][0][fov].ravel(), 1, full=True) for j in range(nflows)])
    brs = [np.sqrt(br[0]/npts) for br in brs]
    print('Balltrack residuals from fit: ', brs[0])
    b_alphas, b_offsets = map(list, zip(*bps))
    # Calculate residuals RMSE
    error = [np.abs(v_stein_sm[i][j][0][fov] - bvs[j][0][fov]*u).ravel() for j in range(nflows)]
    RMSEs = [np.sqrt(np.mean((v_stein_sm[i][j][0][fov] - bvs[j][0][fov]*u)**2)) for j in range(nflows)]
    # print('RMSE Balltracking = ',  b_RMSEs[0])
    # Relative error (Mean Absolute Percentage Error: MAPE)
    MAPE_field = [np.abs((v_stein_sm[i][j][2][fov] - bvsm[j][fov]*u)/v_stein_sm[i][j][2][fov]).ravel()*100 for j in range(nflows)]
    df1 = pd.concat([pd.DataFrame({'error':error[j], 'MAPE': MAPE_field[j], 'nframes':nframes[j], 'FWHM':fwhm_i, 'kernel':kernel, 'algorithm':'Balltracking'}) for j in range(nflows)])
    
    bMAPE = [np.mean(bMAPE_field[j]) for j in range(nflows)]
    # Correlations between Balltracking and simulation
    bcorrs = [calc_c_pearson(v_stein_sm[i][j][0], bvs[j][0], v_stein_sm[i][j][1], bvs[j][1], fov=fov) for j in range(len(tranges))]
    df2 = pd.DataFrame({'nframes':nframes, 'slope':b_alphas, 'RMSE':RMSEs, 'MAPE':bMAPE, 'correlation':bcorrs, 'FWHM':fwhm_i, 'kernel':kernel, 'algorithm':'Balltracking'})
    
    dfs1.append(df1)
    dfs2.append(df2)

bdf1 = pd.concat(dfs1)
bdf2 = pd.concat(dfs2)
display(bdf1.head())
display(bdf2.head())
# Out:
# Balltrack residuals from fit:  264.5569499267419
# Balltrack residuals from fit:  202.66468221356286
# Balltrack residuals from fit:  168.2897909486124
# Balltrack residuals from fit:  141.0357289371228
# Balltrack residuals from fit:  121.78357074400066
#         error        MAPE  nframes  FWHM  kernel     algorithm
# 0  348.105590   26.933644       30     7  boxcar  Balltracking
# 1   44.164550   31.406957       30     7  boxcar  Balltracking
# 2  112.306143   18.266929       30     7  boxcar  Balltracking
# 3  183.047355  201.872616       30     7  boxcar  Balltracking
# 4  205.521035   20.663170       30     7  boxcar  Balltracking
#    nframes     slope        RMSE       MAPE  correlation  FWHM  kernel  \
# 0       30  0.998625  265.119718  28.254120     0.901337     7  boxcar
# 1       35  1.006843  250.677171  27.701850     0.912415     7  boxcar
# 2       40  1.015598  235.953154  24.493964     0.920735     7  boxcar
# ...

# %% [markdown]
# ### FLCT data

# %%
# Load fits files
datadir_flct = os.path.expanduser('~/Data/Ben/SteinSDO/FLCT_Raphael/output_FLCT_sigma4')
fvx_files = sorted((glob.glob(os.path.join(datadir_flct, 'FLCT_vx*.fits'))))
fvy_files = sorted((glob.glob(os.path.join(datadir_flct, 'FLCT_vy*.fits'))))

# %%
# Average over time
fvs = [load_vel_mean((fvx_files, fvy_files), trange) for trange in tranges]

# %%
v_stein_sm[1][0][2][fov].max()
# Out:
# 1938.251374493863

# %%
dfs1 = []
dfs2 = []

for i, fwhm_i in enumerate(fwhms):
    if fwhm_i == 7:
        fvs2 = [np.array([fv[0], fv[1], np.sqrt(fv[0][:]**2 + fv[1][:]**2)]) for fv in fvs]
    else:
        # Smooth Stein velocities
        fvs2 = [smooth_vel(fv, fwhm_i, kernel=kernel) for fv in fvs]
        
    # Fit FLCT to Stein simulation
    fps, frs, _, _, _ = zip(*[np.polyfit(fvs2[j][0][fov].ravel()*u, v_stein_sm[i][j][0][fov].ravel(), 1, full=True) for j in range(nflows)])
    frs = [np.sqrt(fr[0]/npts) for fr in frs]
    print('FLCT residuals from fit: ', frs[0])
    f_alphas, f_offsets = map(list, zip(*fps))
    # Calculate residuals RMSE
    error = [np.abs(v_stein_sm[i][j][0][fov] - fvs2[j][0][fov]*u).ravel() for j in range(nflows)]
    RMSE_uncal = [np.sqrt(np.mean((v_stein_sm[i][j][0][fov] - fvs2[j][0][fov]*u)**2)) for j in range(nflows)]
    # print('RMSE FLCT (uncalibrated) = ',  fRMSE_uncals[0])
    # Relative error (Mean Absolute Percentage Error: MAPE)
    MAPE_field = [np.abs((v_stein_sm[i][j][2][fov] - bvsm[j][fov]*u)/v_stein_sm[i][j][2][fov]).ravel()*100 for j in range(nflows)]
    df1 = pd.concat([pd.DataFrame({'error':error[j], 'MAPE': MAPE_field[j], 'nframes':nframes[j], 'FWHM':fwhm_i, 'kernel':kernel, 'algorithm':'FLCT'}) for j in range(nflows)])  
    
    fMAPE = [np.mean(np.abs((v_stein_sm[i][j][2][fov] - fvs2[j][2][fov]*u)/v_stein_sm[i][j][2][fov]))*100 for j in range(nflows)]
    # Correlations between FLCT and simulation
    fcorrs = [calc_c_pearson(v_stein_sm[i][j][0], fvs2[j][0], v_stein_sm[i][j][1], fvs2[j][1], fov=fov) for j in range(nflows)]
    df2 = pd.DataFrame({'nframes':nframes, 'slope':f_alphas, 'RMSE':RMSE_uncal, 'MAPE':fMAPE, 'correlation':fcorrs, 'FWHM':fwhm_i, 'kernel':kernel, 'algorithm':'FLCT'})
    dfs1.append(df1)
    dfs2.append(df2)
    
fdf1 = pd.concat(dfs1)
fdf2 = pd.concat(dfs2)
display(fdf1.head())
display(fdf2.head())
# Out:
# FLCT residuals from fit:  277.6707629125091
# FLCT residuals from fit:  216.1678588484809
# FLCT residuals from fit:  175.26150217716477
# FLCT residuals from fit:  148.0533042767364
# FLCT residuals from fit:  127.29215907033837
#         error       MAPE  nframes  FWHM  kernel algorithm
# 0  522.198335  53.456049       30     7  boxcar      FLCT
# 1   23.725331  22.544314       30     7  boxcar      FLCT
# 2   29.527903  71.891370       30     7  boxcar      FLCT
# 3  463.549526  19.849822       30     7  boxcar      FLCT
# 4  278.502024  31.076815       30     7  boxcar      FLCT
#    nframes     slope        RMSE       MAPE  correlation  FWHM  kernel  \
# 0       30  1.209758  295.760031  40.119170     0.886128     7  boxcar
# 1       35  1.239754  279.116937  42.388135     0.901866     7  boxcar
# 2       40  1.263891  267.963815  37.658424     0.912868     7  boxcar
# 3       45  1.281695  259.744487  37.963824     0.920165     7  boxcar
# ...

# %%
df1 = pd.concat([bdf1, fdf1])
df2 = pd.concat([bdf2, fdf2])

# %%
import seaborn as sns
sns.set(font_scale=2)
sns.set_style('whitegrid')
# %matplotlib inline

# %%
#fig, ax = plt.subplots(figsize=(10, 8))
g1 = sns.relplot(data=df_boxcar, x='nframes', y='correlation', style='algorithm', hue='FWHM', size='FWHM', kind='line', legend='full', 
            palette='deep', height=8)
g1.set(xlabel='Time average [min]')
plt.savefig(PurePath(outputdir, 'correlation.png'))

# %%
g2 = sns.relplot(data=df_boxcar, x='nframes', y='RMSE', style='algorithm', hue='FWHM', size='FWHM', kind='line', legend='full', 
            palette='deep', height=8)
g2.set(xlabel='Time average [min]', ylabel='RMSE [m/s]')
plt.savefig(PurePath(outputdir, 'rmse.png'))

# %%
g3 = sns.relplot(data=df_boxcar, x='nframes', y='MAPE', style='algorithm', hue='FWHM', size='FWHM', kind='line', legend='full', 
            palette='deep', height=8)
g3.set(xlabel='Time average [min]', ylabel='MAPE [%]')
plt.savefig(PurePath(outputdir, 'mape.png'))

# %%
x = np.arange(-2000, 2000, 100)

# %%
# %matplotlib inline
fig, ax = plt.subplots(1,2, figsize = (16,8))

idx=0
flct_fit = np.poly1d(fps[idx])(x)
b_fit = np.poly1d(bps[idx])(x)

ax[0].scatter(fvs[idx][0][fov].ravel()*u, v_stein_sm[idx][0][fov].ravel(), marker='+', s=20, color='black', alpha=0.7, label = 'FLCT       [C={:1.2f}] [RMSE={:1.0f} m/s]'.format(fcorrs[idx], fRMSE_uncals[idx]))
ax[0].scatter(bvs[idx][0][fov].ravel()*u, v_stein_sm[idx][0][fov].ravel(), marker='o', s=6, color='orange', alpha=1.0, label = 'Balltrack [C={:1.2f}] [RMSE={:1.0f} m/s]'.format(bcorrs[idx], bRMSEs[idx]))

ax[0].plot(x, flct_fit, color='black', label='FLCT (fit)       [s={:1.1f}] '.format(fps[idx][0]))
ax[0].plot(x, b_fit, color='red', label='Balltrack (fit)  [s={:1.1f}] '.format(bps[idx][0]))

ax[0].axis([-2000, 2000, -2000, 2000])
ax[0].set_xlabel(r'$v_x$ (tracking) [m/s]')
ax[0].set_ylabel(r'$v_x$ (simulation) [m/s]')
ax[0].legend(prop={'size': 12}, loc='upper left')
ax[0].set_title('FWHM = 7px ; Time average = {:d} min'.format(tranges[idx][1]))
ax[0].grid(True)
ax[0].set_aspect('equal')
ax[0].axis([-1500, 1500, -1500, 1500])

idx=66
flct_fit = np.poly1d(fps[idx])(x)
b_fit = np.poly1d(bps[idx])(x)

ax[1].scatter(fvs[idx][0][fov].ravel()*u, v_stein_sm[idx][0][fov].ravel(), marker='+', s=20, color='black', alpha=0.7, label = 'FLCT       [C={:1.2f}] [RMSE={:1.0f} m/s]'.format(fcorrs[idx], fRMSE_uncals[idx]))
ax[1].scatter(bvs[idx][0][fov].ravel()*u, v_stein_sm[idx][0][fov].ravel(), marker='o', s=6, color='orange', alpha=1.0, label = 'Balltrack [C={:1.2f}] [RMSE={:1.0f} m/s]'.format(bcorrs[idx], bRMSEs[idx]))

ax[1].plot(x, flct_fit, color='black', label='FLCT (fit)       [s={:1.1f}] '.format(fps[idx][0]))
ax[1].plot(x, b_fit, color='red', label='Balltrack (fit)  [s={:1.1f}] '.format(bps[idx][0]))

ax[1].axis([-2000, 2000, -2000, 2000])
ax[1].set_xlabel(r'$v_x$ (tracking) [m/s]')
ax[1].set_ylabel(r'$v_x$ (simulation) [m/s]')
ax[1].legend(prop={'size': 12}, loc='upper left')
ax[1].set_title('FWHM = 7px ; Time average = {:d} min'.format(tranges[idx][1]))
ax[1].grid(True)
ax[1].set_aspect('equal')
ax[1].axis([-1500, 1500, -1500, 1500])


# plt.tight_layout()
# plt.show()
# plt.savefig(os.path.join(outputdir, 'flct_uncalibrated_{:02d}_flct_sigma4.png'.format(idx)), dpi=300)

# %% [markdown]
# ### Plot spatially-averaged scaling error as a function of time average

# %%
idx = 66

flct_fit = np.poly1d(fps[idx])(x)
b_fit = np.poly1d(bps[idx])(x)


# %matplotlib inline
fig, ax = plt.subplots(1,2, figsize = (16,8))


ax[0].plot(nframes, f_alphas, label='FLCT')
ax[0].plot(nframes, b_alphas, label='Balltrack')
ax[0].set_xlabel('Time average [min]')
ax[0].set_ylabel(r'Scaling error factor $\alpha$')
ax[0].grid(True)
ax[0].legend(fontsize=12)

ax[1].plot(nframes, bcorrs, color='black', ls='-', label=f'C (Balltrack)')
ax[1].plot(nframes, fcorrs, color='gray', ls='--', label=f'C (FLCT)]')
ax[1].set_xticks(np.arange(50, 360, 50))

ax[1].set_xlabel('Time average [min]')
ax[1].set_ylabel('Correlation')
ax[1].set_ylim([0.85, 1.0])
# ax[1].axvline(x=tranges[idx][1], ls='-', color='gray', linewidth=1)
# ax[1].text(tranges[idx][1]+3, 0.89, f'{tranges[idx][1]} min', rotation='vertical', fontsize=14, color='gray')
ax[1].xaxis.grid(True)
ax[1].grid(ls='-')
ax[1].legend(loc='lower left', fontsize=12)

ax3 = ax[1].twinx()
# ax3.plot(nframes, bRMSEs, ls='-.', color='red', label=f'Balltrack [RMSE ={int(round(bRMSEs[idx]))} m/s]')
# ax3.plot(nframes, fRMSE_uncals, ls=':', color='blue', label=f'FLCT [RMSE ={int(round(fRMSE_uncals[idx]))} m/s]')
ax3.plot(nframes, bRMSEs, ls='-.', color='red', label=f'RMSE (Balltrack)')
ax3.plot(nframes, fRMSE_uncals, ls=':', color='blue', label=f'RMSE (FLCT)')
#ax3.plot(nframes, fRMSE_cals, ls=':', color='green', label=f'FLCT calibrated [RMSE ={int(round(fRMSE_cals[idx]))} m/s]')
ax3.set_ylabel('RMSE [m/s]')
ax3.set_ylim([65, 280])
ax3.legend(loc='lower right', fontsize=12)
plt.tight_layout()

# %% [markdown]
# ### Drift test

# %% [markdown]
# ### Calibrate FLCT like Balltracking: apply drift-based "scaling" coefficient from linear fit

# %%
# Fit again on calibrated for sanity check and check residuals
# Calibrate velocity using linear fit
fvxs_cal = [fvx * u * fps[i][0] + fps[i][1] for i,fvx in enumerate(fvxs)]
fRMSE_cals = [np.sqrt(np.mean((vx_stein_sm[i][fov] - fvxs_cal[i][fov])**2)) for i in range(nflows)]
# This RMSE is supposed to be equal to or very close to what we get from the 1st fit of uncalibrated data. 
print('RMSE FLCT (calibrated) = ',  fRMSE_cals[0])

fp_cals, fr_cals, _, _, _ = zip(*[np.polyfit(fvxs_cal[i][fov].ravel(), vx_stein_sm[i][fov].ravel(), 1, full=True) for i in range(nflows)])
fr_cals = [np.sqrt(fr_cal[0]/npts) for fr_cal in fr_cals]

flct_fit = np.poly1d(fps[idx])(x)
flct_fit_cal = np.poly1d(fp_cals[idx])(x)
b_fit = np.poly1d(bps[idx])(x)

idx = 0
# %matplotlib inline
fig, ax = plt.subplots(1,2, figsize = (10,6))

ax[0].scatter(fvxs_cal[idx][fov].ravel()*u, vx_stein_sm[idx][fov].ravel(), marker='+', s=20, color='black', alpha=0.7, label = 'FLCT (corrected)')
ax[0].scatter(bvxs[idx][fov].ravel()*u, vx_stein_sm[idx][fov].ravel(), marker='o', s=6, color='orange', alpha=1.0, label =     'Balltrack')

ax[0].plot(x, flct_fit_cal, color='black', label='FLCT (fit)')
ax[0].plot(x, b_fit, color='red', label='Balltrack (fit)')


ax[0].axis([-2000, 2000, -2000, 2000])
ax[0].set_xlabel(r'$v_x$ (measured) [m/s]')
ax[0].set_ylabel(r'$v_x$ (simulation) [m/s]')
ax[0].legend(prop={'size': 12}, loc='upper left')
ax[0].set_title('Balltracking & FLCT (calibrated)')
ax[0].text(-800, -1800, 'Time average = {:d} min'.format(tranges[idx][1]), fontsize=14)

ax[1].plot(nframes, bcorrs, color='black', ls='-', label=f'Balltrack [C={bcorrs[idx]:{2}.{3}}]')
ax[1].plot(nframes, fcorrs, color='gray', ls='--', label=f'FLCT [C={fcorrs[idx]:{2}.{3}}]')
ax[1].axvline(x=tranges[idx][1], ls='-', color='black')
ax[1].set_title('Pearson Correlation & RMSE vs')
ax[1].set_xlabel('Time average (min)')
ax[1].set_ylabel('Correlation')
ax[1].set_ylim([0.85, 1.0])
ax[1].text(tranges[idx][1]+10, 0.89, f'{tranges[idx][1]} min', rotation='vertical', fontsize=14)
ax[1].xaxis.grid(True)
ax[1].grid(ls='-')
ax[1].legend(loc='upper center')

ax3 = ax[1].twinx()
ax3.plot(nframes, bRMSEs, ls='-.', color='red', label=f'Balltrack [RMSE ={int(round(bRMSEs[idx]))} m/s]')
ax3.plot(nframes, fRMSE_cals, ls=':', label=f'FLCT [RMSE ={int(round(fRMSE_cals[idx]))} m/s]')
ax3.set_ylabel('RMSE (m/s)')
ax3.set_ylim([65, 280])
ax3.legend(loc='lower right')
plt.tight_layout()
