# %%
# %cd /Users/rattie/Dev/sdo_tracking_framework
import os, glob
import time
import numpy as np
from scipy.io import readsav
import matplotlib.pyplot as plt
import fitstools
import fitsio
import balltracking.balltrack as blt
from astropy.io import fits
# Out:
# /Users/rattie/Dev/sdo_tracking_framework

# %%
def balltrack_calibration(datafiles, fwhm, fov_slices, reprocess_bt, use_existing):

    # Select only a subset of nframes files
    selected_files = datafiles[0:nframes]
    # Load the nt images
    images = fitstools.fitsread(selected_files)
    
    start_time_clock = time.clock()
    if reprocess_bt:
         # Must make even dimensions for the fast fourier transform
        images2 = np.zeros([264, 264, images.shape[2]])
        images2[0:263, 0:263, :] = images.copy()
        images2[263, :] = images.mean()
        images2[:, 263] = images.mean() 
        # Ball radius
        rs = 2
        # depth factor
        dp = 0.3
        # Multiplier to the standard deviation.
        sigma_factor = 1
        # Nb of integration steps between images
        intsteps = 5
        cal = blt.Calibrator(images2, drift_rates, nframes, rs, dp, sigma_factor, outputdir,
                             intsteps=intsteps,
                             output_prep_data=False, use_existing=use_existing,
                             nthreads=5)

        ballpos_top_list, ballpos_bottom_list = cal.balltrack_all_rates()
    else:
        print('Load existing tracked data at all rates')
        ballpos_top_list = np.load(os.path.join(outputdir, 'ballpos_top_list.npy'))
        ballpos_bottom_list = np.load(os.path.join(outputdir, 'ballpos_bottom_list.npy'))

    duration_time_clock = time.clock() - start_time_clock 
    print('duration_time_clock:   ', duration_time_clock)
    
    trange = [0, nframes]
    xrates = np.array(drift_rates)[:, 0]
    a_top, vxfit_top, vxmeans_top, residuals_top = blt.fit_calibration(ballpos_top_list, xrates, trange, fwhm,
                                                        images.shape[0:2], fov_slices,
                                                        return_flow_maps=False)
    a_bottom, vxfit_bottom, vxmeans_bottom, residuals_bottom = blt.fit_calibration(ballpos_bottom_list, xrates, trange, fwhm,
                                                                 images.shape[0:2], fov_slices,
                                                                 return_flow_maps=False)

    return a_top, vxfit_top, vxmeans_top, residuals_top, a_bottom, vxfit_bottom, vxmeans_bottom, residuals_bottom


def average_calibration(vxfit_top, vxfit_bottom, vx_rates):
    # Fit the averaged calibrated balltrack velocity
    vxmeans_bt = (vxfit_top + vxfit_bottom)/2
    # #vxmeans_bt -= vxmeans_bt[4]
    p = np.polyfit(vx_rates, vxmeans_bt, 1)
    a_avg = 1 / p[0]
    vxfit_avg = a_avg * (vxmeans_bt - p[1])
    # # Calculate residuals
    bt_residuals = np.abs(vxmeans_bt - vx_rates)
    #bt_residuals_fit = np.abs(vxfit_avg - vx_rates)
    print('a_avg = {:0.2f}, p[1] = {:0.2f}'.format(a_avg, p[1]))
    return vxmeans_bt, a_avg, vxfit_avg, bt_residuals



def dv_analysis(vx_files, vx_ratesu, fov_slices):
    # Benoit's data are already in physical units (m/s). The drift rates must also be in that unit.
    vxmeans = []
    for i in range(len(vx_files)):
        vx = fitsio.read(vx_files[i])
        vxmeans.append(vx[fov_slices[1], fov_slices[0]].mean())
    vxmeans = np.array(vxmeans)# - vxmeans[4]
    ## Calibration parameters: y_measured = p0*x_true + p1 => true = (measured - p1)*1/p0
    p = np.polyfit(vx_ratesu, vxmeans, 1)
    a_v = 1 / p[0]
    vxfits = a_v * (vxmeans - p[1])
    # Calculate residuals
    residuals0 = np.abs(vxmeans - vx_ratesu)
    residuals = np.abs(vxfits - vx_ratesu)

    return vxmeans, a_v, vxfits, residuals0, residuals

# %%
# input data, list of files
# glob.glob does not order numbered files by defaultl, the order is as appeared in the file system.
datafiles = sorted(glob.glob('/Users/rattie/Data/Ben/SteinSDO/SDO_int*.fits'))
# output directory for the drifting images
outputdir = '/Users/rattie/Data/Ben/SteinSDO/calibration/'
# output directory for the plots
plotdir = '/Users/rattie/Data/Ben/SteinSDO/calibration/FLCT_Benoit/FLCT_drift_filt_non_norm/output_flct_sigma7/'
# Set if we balltrack again or use previous results
reprocess_bt = True
# Set if we use existing drifted images
use_existing = True
    
nframes = 80
fwhm = 7
npts = 9
vx_rates = np.linspace(-0.2, 0.2, npts)
# The drift can optionnally be on both direction, not just on the x-axis
drift_rates = np.stack((vx_rates, np.zeros(npts)), axis=1).tolist()
# Select a subfield excluding edge effects
imsize = 263 # actual size is 264 but original size was 263 then padded to 264 to make it even for the Fourier transform
trim = int(vx_rates.max() * nframes + fwhm + 2)
fov_slices = np.s_[trim:imsize - trim, trim:imsize-trim]

unit = 368000 / 60 # m/s
unit_str = '[m/s]'
vx_ratesu = vx_rates * unit
bar_labels = ['{:0.0f}'.format(vxrate) for vxrate in vx_ratesu]

# %% [markdown]
# ## Balltracking

# %%
    # Select a subfield excluding edge effects
    fov_slices_bt = [fov_slices, ]
    ##########################################
    ######  Smoothing at FWHM = 7 px #########
    fwhm = 7
    a_top1, vxfit_top1, vxmeans_top1, res_top1, a_bot1, vxfit_bot1, vxmeans_bot1, res_bot1 = balltrack_calibration(datafiles, fwhm, fov_slices_bt, reprocess_bt, use_existing)
    vxmeans_bt1, a_avg1, vxfit_avg1, bt_residuals1 = average_calibration(vxfit_top1, vxfit_bot1, vx_rates)
# Out:
# Reading existing drift images at rate: [-0.20, 0.00] px/frame
# Reading existing drift images at rate: [-0.15, 0.00] px/frame
# Tracking direction forward/top, frame 0
# Tracking direction forward/top, frame 1
# Tracking direction forward/top, frame 2
# Tracking direction forward/top, frame 3
# Tracking direction forward/top, frame 0
# Tracking direction forward/top, frame 4
# Tracking direction forward/top, frame 1
# Tracking direction forward/top, frame 5
# Tracking direction forward/top, frame 2
# Tracking direction forward/top, frame 6
# Tracking direction forward/top, frame 3
# Tracking direction forward/top, frame 7
# Tracking direction forward/top, frame 4
# Reading existing drift images at rate: [-0.10, 0.00] px/frame
# Tracking direction forward/top, frame 8
# Tracking direction forward/top, frame 5
# Tracking direction forward/top, frame 9
# Tracking direction forward/top, frame 6
# Tracking direction forward/top, frame 10
# Tracking direction forward/top, frame 7
# Tracking direction forward/top, frame 11
# Tracking direction forward/top, frame 8
# Tracking direction forward/top, frame 12
# Tracking direction forward/top, frame 9
# Tracking direction forward/top, frame 0
# Tracking direction forward/top, frame 13
# Tracking direction forward/top, frame 10
# Tracking direction forward/top, frame 1
# Tracking direction forward/top, frame 14
# Tracking direction forward/top, frame 11
# Tracking direction forward/top, frame 15
# Tracking direction forward/top, frame 2
# Tracking direction forward/top, frame 12
# Tracking direction forward/top, frame 16
# Tracking direction forward/top, frame 3
# Tracking direction forward/top, frame 13
# Tracking direction forward/top, frame 17
# Tracking direction forward/top, frame 4
# Tracking direction forward/top, frame 14
# Tracking direction forward/top, frame 18
# Tracking direction forward/top, frame 5
# Tracking direction forward/top, frame 15
# Tracking direction forward/top, frame 19
# Tracking direction forward/top, frame 6
# Reading existing drift images at rate: [-0.05, 0.00] px/frame
# Tracking direction forward/top, frame 16
# Tracking direction forward/top, frame 20
# Tracking direction forward/top, frame 7
# Tracking direction forward/top, frame 17
# Tracking direction forward/top, frame 21
# Tracking direction forward/top, frame 8
# Tracking direction forward/top, frame 18
# Tracking direction forward/top, frame 22
# Tracking direction forward/top, frame 9
# Tracking direction forward/top, frame 19
# Tracking direction forward/top, frame 23
# Tracking direction forward/top, frame 10
# Tracking direction forward/top, frame 20
# Tracking direction forward/top, frame 0
# Tracking direction forward/top, frame 11
# Tracking direction forward/top, frame 24
# Tracking direction forward/top, frame 21
# Tracking direction forward/top, frame 12
# Tracking direction forward/top, frame 25
# Tracking direction forward/top, frame 1
# Tracking direction forward/top, frame 22
# Tracking direction forward/top, frame 13
# Tracking direction forward/top, frame 26
# Tracking direction forward/top, frame 2
# Tracking direction forward/top, frame 23
# Tracking direction forward/top, frame 27
# Tracking direction forward/top, frame 14
# Tracking direction forward/top, frame 3
# Tracking direction forward/top, frame 24
# Tracking direction forward/top, frame 28
# Tracking direction forward/top, frame 15
# Tracking direction forward/top, frame 4
# Tracking direction forward/top, frame 25
# Tracking direction forward/top, frame 16
# Tracking direction forward/top, frame 29
# Tracking direction forward/top, frame 5
# Tracking direction forward/top, frame 26
# Tracking direction forward/top, frame 17
# Tracking direction forward/top, frame 30
# Tracking direction forward/top, frame 6
# Tracking direction forward/top, frame 27
# Tracking direction forward/top, frame 18
# Tracking direction forward/top, frame 31
# Tracking direction forward/top, frame 7
# Tracking direction forward/top, frame 28
# Tracking direction forward/top, frame 19
# Reading existing drift images at rate: [0.00, 0.00] px/frame
# Tracking direction forward/top, frame 32
# Tracking direction forward/top, frame 8
# Tracking direction forward/top, frame 29
# Tracking direction forward/top, frame 20
# Tracking direction forward/top, frame 33
# Tracking direction forward/top, frame 9
# Tracking direction forward/top, frame 30
# Tracking direction forward/top, frame 21
# Tracking direction forward/top, frame 34
# Tracking direction forward/top, frame 10
# Tracking direction forward/top, frame 22
# Tracking direction forward/top, frame 31
# Tracking direction forward/top, frame 35
# Tracking direction forward/top, frame 11
# Tracking direction forward/top, frame 32
# Tracking direction forward/top, frame 23
# Tracking direction forward/top, frame 36
# Tracking direction forward/top, frame 12
# Tracking direction forward/top, frame 24
# Tracking direction forward/top, frame 33
# Tracking direction forward/top, frame 0
# Tracking direction forward/top, frame 37
# Tracking direction forward/top, frame 13
# Tracking direction forward/top, frame 25
# Tracking direction forward/top, frame 34
# Tracking direction forward/top, frame 14
# Tracking direction forward/top, frame 38
# Tracking direction forward/top, frame 1
# Tracking direction forward/top, frame 26
# Tracking direction forward/top, frame 15
# Tracking direction forward/top, frame 35
# Tracking direction forward/top, frame 39
# Tracking direction forward/top, frame 2
# Tracking direction forward/top, frame 27
# Tracking direction forward/top, frame 36
# Tracking direction forward/top, frame 16
# Tracking direction forward/top, frame 3
# Tracking direction forward/top, frame 40
# Tracking direction forward/top, frame 28
# Tracking direction forward/top, frame 37
# Tracking direction forward/top, frame 41
# Tracking direction forward/top, frame 4
# Tracking direction forward/top, frame 17
# Tracking direction forward/top, frame 29
# Tracking direction forward/top, frame 38
# Tracking direction forward/top, frame 42
# Tracking direction forward/top, frame 18
# Tracking direction forward/top, frame 5
# Tracking direction forward/top, frame 30
# Tracking direction forward/top, frame 43
# Tracking direction forward/top, frame 39
# Tracking direction forward/top, frame 6
# Tracking direction forward/top, frame 19
# Tracking direction forward/top, frame 44
# Tracking direction forward/top, frame 40
# Tracking direction forward/top, frame 31
# Tracking direction forward/top, frame 20
# Tracking direction forward/top, frame 7
# Tracking direction forward/top, frame 41
# Tracking direction forward/top, frame 45
# Tracking direction forward/top, frame 8
# Tracking direction forward/top, frame 21
# Tracking direction forward/top, frame 32
# Tracking direction forward/top, frame 42
# Tracking direction forward/top, frame 46
# Tracking direction forward/top, frame 9
# Tracking direction forward/top, frame 33
# Tracking direction forward/top, frame 22
# Tracking direction forward/top, frame 43
# Tracking direction forward/top, frame 47
# Tracking direction forward/top, frame 10
# Tracking direction forward/top, frame 23
# Tracking direction forward/top, frame 34
# Tracking direction forward/top, frame 44
# Tracking direction forward/top, frame 48
# Tracking direction forward/top, frame 11
# Tracking direction forward/top, frame 24
# Tracking direction forward/top, frame 35
# Tracking direction forward/top, frame 45
# Tracking direction forward/top, frame 49
# Tracking direction forward/top, frame 12
# Tracking direction forward/top, frame 25
# Tracking direction forward/top, frame 36
# Tracking direction forward/top, frame 50
# Tracking direction forward/top, frame 46
# Tracking direction forward/top, frame 13
# Tracking direction forward/top, frame 26
# Tracking direction forward/top, frame 37
# Tracking direction forward/top, frame 47
# Tracking direction forward/top, frame 51
# Tracking direction forward/top, frame 14
# Tracking direction forward/top, frame 27
# Tracking direction forward/top, frame 38
# Tracking direction forward/top, frame 48
# Tracking direction forward/top, frame 52
# Tracking direction forward/top, frame 15
# Tracking direction forward/top, frame 28
# Tracking direction forward/top, frame 39
# Tracking direction forward/top, frame 49
# Tracking direction forward/top, frame 53
# Tracking direction forward/top, frame 16
# Tracking direction forward/top, frame 29
# Tracking direction forward/top, frame 40
# Tracking direction forward/top, frame 50
# Tracking direction forward/top, frame 54
# Tracking direction forward/top, frame 17
# Tracking direction forward/top, frame 30
# Tracking direction forward/top, frame 41
# Tracking direction forward/top, frame 51
# Tracking direction forward/top, frame 55
# Tracking direction forward/top, frame 18
# Tracking direction forward/top, frame 31
# Tracking direction forward/top, frame 42
# Tracking direction forward/top, frame 52
# Tracking direction forward/top, frame 56
# Tracking direction forward/top, frame 19
# Tracking direction forward/top, frame 32
# Tracking direction forward/top, frame 43
# Tracking direction forward/top, frame 53
# Tracking direction forward/top, frame 57
# Tracking direction forward/top, frame 20
# Tracking direction forward/top, frame 33
# Tracking direction forward/top, frame 44
# Tracking direction forward/top, frame 54
# Tracking direction forward/top, frame 58
# Tracking direction forward/top, frame 21
# Tracking direction forward/top, frame 34
# Tracking direction forward/top, frame 55
# Tracking direction forward/top, frame 45
# Tracking direction forward/top, frame 22
# Tracking direction forward/top, frame 59
# Tracking direction forward/top, frame 35
# Tracking direction forward/top, frame 56
# Tracking direction forward/top, frame 46
# Tracking direction forward/top, frame 23
# Tracking direction forward/top, frame 60
# Tracking direction forward/top, frame 36
# Tracking direction forward/top, frame 47
# Tracking direction forward/top, frame 57
# Tracking direction forward/top, frame 24
# Tracking direction forward/top, frame 61
# Tracking direction forward/top, frame 37
# Tracking direction forward/top, frame 58
# Tracking direction forward/top, frame 48
# Tracking direction forward/top, frame 25
# Tracking direction forward/top, frame 62
# Tracking direction forward/top, frame 38
# Tracking direction forward/top, frame 59
# Tracking direction forward/top, frame 49
# Tracking direction forward/top, frame 26
# Tracking direction forward/top, frame 63
# Tracking direction forward/top, frame 39
# Tracking direction forward/top, frame 60
# Tracking direction forward/top, frame 50
# Tracking direction forward/top, frame 27
# Tracking direction forward/top, frame 64
# Tracking direction forward/top, frame 40
# Tracking direction forward/top, frame 61
# Tracking direction forward/top, frame 51
# Tracking direction forward/top, frame 28
# Tracking direction forward/top, frame 65
# Tracking direction forward/top, frame 41
# Tracking direction forward/top, frame 62
# Tracking direction forward/top, frame 52
# Tracking direction forward/top, frame 29
# Tracking direction forward/top, frame 66
# Tracking direction forward/top, frame 42
# Tracking direction forward/top, frame 63
# Tracking direction forward/top, frame 53
# Tracking direction forward/top, frame 30
# Tracking direction forward/top, frame 67
# Tracking direction forward/top, frame 43
# Tracking direction forward/top, frame 64
# Tracking direction forward/top, frame 54
# Tracking direction forward/top, frame 31
# Tracking direction forward/top, frame 68
# Tracking direction forward/top, frame 44
# Tracking direction forward/top, frame 65
# Tracking direction forward/top, frame 55
# Tracking direction forward/top, frame 32
# Tracking direction forward/top, frame 69
# Tracking direction forward/top, frame 45
# Tracking direction forward/top, frame 66
# Tracking direction forward/top, frame 56
# Tracking direction forward/top, frame 33
# Tracking direction forward/top, frame 70
# Tracking direction forward/top, frame 46
# Tracking direction forward/top, frame 67
# Tracking direction forward/top, frame 57
# Tracking direction forward/top, frame 34
# Tracking direction forward/top, frame 71
# Tracking direction forward/top, frame 47
# Tracking direction forward/top, frame 68
# Tracking direction forward/top, frame 58
# Tracking direction forward/top, frame 35
# Tracking direction forward/top, frame 72
# Tracking direction forward/top, frame 48
# Tracking direction forward/top, frame 69
# Tracking direction forward/top, frame 59
# Tracking direction forward/top, frame 36
# Tracking direction forward/top, frame 73
# Tracking direction forward/top, frame 49
# Tracking direction forward/top, frame 70
# Tracking direction forward/top, frame 60
# Tracking direction forward/top, frame 37
# Tracking direction forward/top, frame 74
# Tracking direction forward/top, frame 50
# Tracking direction forward/top, frame 71
# Tracking direction forward/top, frame 61
# Tracking direction forward/top, frame 38
# Tracking direction forward/top, frame 51
# Tracking direction forward/top, frame 62
# Tracking direction forward/top, frame 75
# Tracking direction forward/top, frame 39
# Tracking direction forward/top, frame 72
# Tracking direction forward/top, frame 52
# Tracking direction forward/top, frame 63
# Tracking direction forward/top, frame 76
# Tracking direction forward/top, frame 40
# Tracking direction forward/top, frame 73
# Tracking direction forward/top, frame 53
# Tracking direction forward/top, frame 64
# Tracking direction forward/top, frame 77
# Tracking direction forward/top, frame 41
# Tracking direction forward/top, frame 74
# Tracking direction forward/top, frame 54
# Tracking direction forward/top, frame 65
# Tracking direction forward/top, frame 78
# Tracking direction forward/top, frame 42
# Tracking direction forward/top, frame 75
# Tracking direction forward/top, frame 55
# Tracking direction forward/top, frame 66
# Tracking direction forward/top, frame 79
# Tracking direction forward/top, frame 43
# Tracking direction forward/top, frame 76
# Tracking direction forward/top, frame 56
# Tracking direction forward/top, frame 67
# Tracking direction backward/top, frame 0
# Tracking direction forward/top, frame 44
# Tracking direction forward/top, frame 77
# Tracking direction forward/top, frame 57
# Tracking direction forward/top, frame 68
# Tracking direction backward/top, frame 1
# Tracking direction forward/top, frame 45
# Tracking direction forward/top, frame 78
# Tracking direction forward/top, frame 58
# Tracking direction forward/top, frame 69
# Tracking direction backward/top, frame 2
# Tracking direction forward/top, frame 46
# Tracking direction forward/top, frame 79
# Tracking direction forward/top, frame 59
# Tracking direction forward/top, frame 70
# Tracking direction forward/top, frame 47
# Tracking direction backward/top, frame 3
# Tracking direction forward/top, frame 60
# Tracking direction forward/top, frame 71
# Tracking direction backward/top, frame 0
# Tracking direction forward/top, frame 48
# Tracking direction backward/top, frame 4
# Tracking direction forward/top, frame 72
# Tracking direction forward/top, frame 61
# Tracking direction backward/top, frame 1
# Tracking direction forward/top, frame 49
# Tracking direction backward/top, frame 5
# Tracking direction forward/top, frame 62
# Tracking direction forward/top, frame 73
# Tracking direction backward/top, frame 2
# Tracking direction forward/top, frame 50
# Tracking direction backward/top, frame 6
# Tracking direction forward/top, frame 74
# Tracking direction forward/top, frame 63
# Tracking direction backward/top, frame 3
# Tracking direction forward/top, frame 51
# Tracking direction backward/top, frame 7
# Tracking direction forward/top, frame 75
# Tracking direction forward/top, frame 64
# Tracking direction backward/top, frame 4
# Tracking direction forward/top, frame 52
# Tracking direction backward/top, frame 8
# Tracking direction forward/top, frame 76
# Tracking direction backward/top, frame 5
# Tracking direction forward/top, frame 65
# Tracking direction forward/top, frame 53
# Tracking direction backward/top, frame 9
# Tracking direction forward/top, frame 77
# Tracking direction backward/top, frame 6
# Tracking direction forward/top, frame 66
# Tracking direction forward/top, frame 54
# Tracking direction backward/top, frame 10
# Tracking direction forward/top, frame 78
# Tracking direction backward/top, frame 7
# Tracking direction forward/top, frame 67
# Tracking direction forward/top, frame 55
# Tracking direction backward/top, frame 11
# Tracking direction forward/top, frame 79
# Tracking direction backward/top, frame 8
# Tracking direction forward/top, frame 68
# Tracking direction forward/top, frame 56
# Tracking direction backward/top, frame 12
# Tracking direction backward/top, frame 9
# Tracking direction forward/top, frame 69
# Tracking direction backward/top, frame 0
# Tracking direction forward/top, frame 57
# Tracking direction backward/top, frame 13
# Tracking direction backward/top, frame 10
# Tracking direction forward/top, frame 70
# Tracking direction backward/top, frame 1
# Tracking direction forward/top, frame 58
# Tracking direction backward/top, frame 11
# Tracking direction backward/top, frame 14
# Tracking direction forward/top, frame 71
# Tracking direction backward/top, frame 2
# Tracking direction forward/top, frame 59
# Tracking direction backward/top, frame 12
# Tracking direction backward/top, frame 15
# Tracking direction forward/top, frame 72
# Tracking direction backward/top, frame 3
# Tracking direction forward/top, frame 60
# Tracking direction backward/top, frame 13
# Tracking direction backward/top, frame 16
# Tracking direction forward/top, frame 73
# Tracking direction backward/top, frame 4
# Tracking direction forward/top, frame 61
# Tracking direction backward/top, frame 14
# Tracking direction backward/top, frame 17
# Tracking direction forward/top, frame 74
# Tracking direction backward/top, frame 5
# Tracking direction forward/top, frame 62
# Tracking direction backward/top, frame 15
# Tracking direction backward/top, frame 18
# Tracking direction forward/top, frame 75
# Tracking direction backward/top, frame 6
# Tracking direction forward/top, frame 63
# Tracking direction backward/top, frame 19
# Tracking direction backward/top, frame 16
# Tracking direction forward/top, frame 76
# Tracking direction backward/top, frame 7
# Tracking direction forward/top, frame 64
# Tracking direction backward/top, frame 17
# Tracking direction backward/top, frame 20
# Tracking direction forward/top, frame 77
# Tracking direction backward/top, frame 8
# Tracking direction forward/top, frame 65
# Tracking direction backward/top, frame 21
# Tracking direction forward/top, frame 78
# Tracking direction backward/top, frame 18
# Tracking direction backward/top, frame 9
# Tracking direction forward/top, frame 66
# Tracking direction backward/top, frame 19
# Tracking direction backward/top, frame 22
# Tracking direction forward/top, frame 79
# Tracking direction backward/top, frame 10
# Tracking direction forward/top, frame 67
# Tracking direction backward/top, frame 20
# Tracking direction backward/top, frame 23
# Tracking direction backward/top, frame 11
# Tracking direction backward/top, frame 0
# Tracking direction forward/top, frame 68
# Tracking direction backward/top, frame 21
# Tracking direction backward/top, frame 24
# Tracking direction backward/top, frame 12
# Tracking direction backward/top, frame 1
# Tracking direction forward/top, frame 69
# Tracking direction backward/top, frame 25
# Tracking direction backward/top, frame 22
# Tracking direction backward/top, frame 13
# Tracking direction backward/top, frame 2
# Tracking direction forward/top, frame 70
# Tracking direction backward/top, frame 26
# Tracking direction backward/top, frame 23
# Tracking direction backward/top, frame 14
# Tracking direction forward/top, frame 71
# Tracking direction backward/top, frame 3
# Tracking direction backward/top, frame 27
# Tracking direction backward/top, frame 24
# Tracking direction backward/top, frame 15
# Tracking direction forward/top, frame 72
# Tracking direction backward/top, frame 4
# Tracking direction backward/top, frame 28
# Tracking direction backward/top, frame 25
# Tracking direction backward/top, frame 16
# Tracking direction forward/top, frame 73
# Tracking direction backward/top, frame 5
# Tracking direction backward/top, frame 29
# Tracking direction backward/top, frame 26
# Tracking direction backward/top, frame 17
# Tracking direction forward/top, frame 74
# Tracking direction backward/top, frame 6
# Tracking direction backward/top, frame 30
# Tracking direction backward/top, frame 27
# Tracking direction backward/top, frame 18
# Tracking direction forward/top, frame 75
# Tracking direction backward/top, frame 7
# Tracking direction backward/top, frame 31
# Tracking direction backward/top, frame 28
# Tracking direction backward/top, frame 19
# Tracking direction forward/top, frame 76
# Tracking direction backward/top, frame 8
# Tracking direction backward/top, frame 29
# Tracking direction backward/top, frame 32
# Tracking direction backward/top, frame 20
# Tracking direction forward/top, frame 77
# Tracking direction backward/top, frame 9
# Tracking direction backward/top, frame 33
# Tracking direction backward/top, frame 30
# Tracking direction backward/top, frame 21
# Tracking direction forward/top, frame 78
# Tracking direction backward/top, frame 10
# Tracking direction backward/top, frame 34
# Tracking direction backward/top, frame 31
# Tracking direction backward/top, frame 22
# Tracking direction forward/top, frame 79
# Tracking direction backward/top, frame 11
# Tracking direction backward/top, frame 32
# Tracking direction backward/top, frame 35
# Tracking direction backward/top, frame 23
# Tracking direction backward/top, frame 12
# Tracking direction backward/top, frame 33
# Tracking direction backward/top, frame 36
# Tracking direction backward/top, frame 0
# Tracking direction backward/top, frame 24
# Tracking direction backward/top, frame 13
# Tracking direction backward/top, frame 37
# Tracking direction backward/top, frame 34
# Tracking direction backward/top, frame 1
# Tracking direction backward/top, frame 25
# Tracking direction backward/top, frame 14
# Tracking direction backward/top, frame 38
# Tracking direction backward/top, frame 35
# Tracking direction backward/top, frame 26
# Tracking direction backward/top, frame 2
# Tracking direction backward/top, frame 15
# Tracking direction backward/top, frame 39
# Tracking direction backward/top, frame 36
# Tracking direction backward/top, frame 3
# Tracking direction backward/top, frame 27
# Tracking direction backward/top, frame 16
# Tracking direction backward/top, frame 40
# Tracking direction backward/top, frame 37
# Tracking direction backward/top, frame 4
# Tracking direction backward/top, frame 28
# Tracking direction backward/top, frame 17
# Tracking direction backward/top, frame 38
# Tracking direction backward/top, frame 41
# Tracking direction backward/top, frame 5
# Tracking direction backward/top, frame 29
# Tracking direction backward/top, frame 18
# Tracking direction backward/top, frame 39
# Tracking direction backward/top, frame 42
# Tracking direction backward/top, frame 6
# Tracking direction backward/top, frame 30
# Tracking direction backward/top, frame 19
# Tracking direction backward/top, frame 40
# Tracking direction backward/top, frame 43
# Tracking direction backward/top, frame 7
# Tracking direction backward/top, frame 31
# Tracking direction backward/top, frame 20
# Tracking direction backward/top, frame 41
# Tracking direction backward/top, frame 44
# Tracking direction backward/top, frame 8
# Tracking direction backward/top, frame 32
# Tracking direction backward/top, frame 21
# Tracking direction backward/top, frame 45
# Tracking direction backward/top, frame 42
# Tracking direction backward/top, frame 9
# Tracking direction backward/top, frame 33
# Tracking direction backward/top, frame 22
# Tracking direction backward/top, frame 46
# Tracking direction backward/top, frame 43
# Tracking direction backward/top, frame 10
# Tracking direction backward/top, frame 34
# Tracking direction backward/top, frame 23
# Tracking direction backward/top, frame 47
# Tracking direction backward/top, frame 44
# Tracking direction backward/top, frame 11
# Tracking direction backward/top, frame 35
# Tracking direction backward/top, frame 24
# Tracking direction backward/top, frame 48
# Tracking direction backward/top, frame 45
# Tracking direction backward/top, frame 12
# Tracking direction backward/top, frame 36
# Tracking direction backward/top, frame 25
# Tracking direction backward/top, frame 49
# Tracking direction backward/top, frame 46
# Tracking direction backward/top, frame 13
# Tracking direction backward/top, frame 37
# Tracking direction backward/top, frame 26
# Tracking direction backward/top, frame 50
# Tracking direction backward/top, frame 47
# Tracking direction backward/top, frame 14
# Tracking direction backward/top, frame 38
# Tracking direction backward/top, frame 27
# Tracking direction backward/top, frame 51
# Tracking direction backward/top, frame 48
# Tracking direction backward/top, frame 15
# Tracking direction backward/top, frame 39
# Tracking direction backward/top, frame 28
# Tracking direction backward/top, frame 52
# Tracking direction backward/top, frame 49
# Tracking direction backward/top, frame 16
# Tracking direction backward/top, frame 40
# Tracking direction backward/top, frame 29
# Tracking direction backward/top, frame 53
# Tracking direction backward/top, frame 50
# Tracking direction backward/top, frame 17
# Tracking direction backward/top, frame 41
# Tracking direction backward/top, frame 30
# Tracking direction backward/top, frame 54
# Tracking direction backward/top, frame 51
# Tracking direction backward/top, frame 18
# Tracking direction backward/top, frame 42
# Tracking direction backward/top, frame 31
# Tracking direction backward/top, frame 55
# Tracking direction backward/top, frame 19
# Tracking direction backward/top, frame 52
# Tracking direction backward/top, frame 43
# Tracking direction backward/top, frame 32
# Tracking direction backward/top, frame 56
# Tracking direction backward/top, frame 53
# Tracking direction backward/top, frame 20
# Tracking direction backward/top, frame 44
# Tracking direction backward/top, frame 33
# Tracking direction backward/top, frame 57
# Tracking direction backward/top, frame 54
# Tracking direction backward/top, frame 21
# Tracking direction backward/top, frame 45
# Tracking direction backward/top, frame 34
# Tracking direction backward/top, frame 58
# Tracking direction backward/top, frame 55
# Tracking direction backward/top, frame 22
# Tracking direction backward/top, frame 46
# Tracking direction backward/top, frame 35
# Tracking direction backward/top, frame 59
# Tracking direction backward/top, frame 56
# Tracking direction backward/top, frame 23
# Tracking direction backward/top, frame 47
# Tracking direction backward/top, frame 36
# Tracking direction backward/top, frame 60
# Tracking direction backward/top, frame 24
# Tracking direction backward/top, frame 57
# Tracking direction backward/top, frame 48
# Tracking direction backward/top, frame 37
# Tracking direction backward/top, frame 61
# Tracking direction backward/top, frame 25
# Tracking direction backward/top, frame 58
# Tracking direction backward/top, frame 49
# Tracking direction backward/top, frame 38
# Tracking direction backward/top, frame 62
# Tracking direction backward/top, frame 26
# Tracking direction backward/top, frame 59
# Tracking direction backward/top, frame 50
# Tracking direction backward/top, frame 39
# Tracking direction backward/top, frame 63
# Tracking direction backward/top, frame 27
# Tracking direction backward/top, frame 60
# Tracking direction backward/top, frame 51
# Tracking direction backward/top, frame 40
# Tracking direction backward/top, frame 64
# Tracking direction backward/top, frame 28
# Tracking direction backward/top, frame 61
# Tracking direction backward/top, frame 52
# Tracking direction backward/top, frame 41
# Tracking direction backward/top, frame 65
# Tracking direction backward/top, frame 29
# Tracking direction backward/top, frame 62
# Tracking direction backward/top, frame 53
# Tracking direction backward/top, frame 42
# Tracking direction backward/top, frame 66
# Tracking direction backward/top, frame 30
# Tracking direction backward/top, frame 63
# Tracking direction backward/top, frame 54
# Tracking direction backward/top, frame 43
# Tracking direction backward/top, frame 67
# Tracking direction backward/top, frame 31
# Tracking direction backward/top, frame 64
# Tracking direction backward/top, frame 55
# Tracking direction backward/top, frame 44
# Tracking direction backward/top, frame 68
# Tracking direction backward/top, frame 32
# Tracking direction backward/top, frame 65
# Tracking direction backward/top, frame 56
# Tracking direction backward/top, frame 45
# Tracking direction backward/top, frame 69
# Tracking direction backward/top, frame 33
# Tracking direction backward/top, frame 66
# Tracking direction backward/top, frame 57
# Tracking direction backward/top, frame 46
# Tracking direction backward/top, frame 70
# Tracking direction backward/top, frame 34
# Tracking direction backward/top, frame 67
# Tracking direction backward/top, frame 58
# Tracking direction backward/top, frame 47
# Tracking direction backward/top, frame 71
# Tracking direction backward/top, frame 35
# Tracking direction backward/top, frame 68
# Tracking direction backward/top, frame 59
# Tracking direction backward/top, frame 48
# Tracking direction backward/top, frame 72
# Tracking direction backward/top, frame 36
# Tracking direction backward/top, frame 69
# Tracking direction backward/top, frame 60
# Tracking direction backward/top, frame 49
# Tracking direction backward/top, frame 73
# Tracking direction backward/top, frame 37
# Tracking direction backward/top, frame 70
# Tracking direction backward/top, frame 61
# Tracking direction backward/top, frame 50
# Tracking direction backward/top, frame 74
# Tracking direction backward/top, frame 38
# Tracking direction backward/top, frame 71
# Tracking direction backward/top, frame 62
# Tracking direction backward/top, frame 51
# Tracking direction backward/top, frame 75
# Tracking direction backward/top, frame 39
# Tracking direction backward/top, frame 72
# Tracking direction backward/top, frame 63
# Tracking direction backward/top, frame 52
# Tracking direction backward/top, frame 76
# Tracking direction backward/top, frame 40
# Tracking direction backward/top, frame 73
# Tracking direction backward/top, frame 64
# Tracking direction backward/top, frame 53
# Tracking direction backward/top, frame 77
# Tracking direction backward/top, frame 41
# Tracking direction backward/top, frame 74
# Tracking direction backward/top, frame 65
# Tracking direction backward/top, frame 54
# Tracking direction backward/top, frame 78
# Tracking direction backward/top, frame 42
# Tracking direction backward/top, frame 75
# Tracking direction backward/top, frame 66
# Tracking direction backward/top, frame 79
# Tracking direction backward/top, frame 55
# Tracking direction backward/top, frame 43
# Tracking direction backward/top, frame 76
# Tracking direction backward/top, frame 67
# Tracking direction backward/top, frame 56
# Tracking direction backward/top, frame 44
# Tracking direction forward/bottom, frame 0
# Tracking direction backward/top, frame 77
# Tracking direction backward/top, frame 68
# Tracking direction backward/top, frame 57
# Tracking direction backward/top, frame 45
# Tracking direction forward/bottom, frame 1
# Tracking direction backward/top, frame 78
# Tracking direction backward/top, frame 69
# Tracking direction backward/top, frame 58
# Tracking direction backward/top, frame 46
# Tracking direction forward/bottom, frame 2
# Tracking direction backward/top, frame 79
# Tracking direction backward/top, frame 70
# Tracking direction backward/top, frame 59
# Tracking direction backward/top, frame 47
# Tracking direction forward/bottom, frame 3
# Tracking direction forward/bottom, frame 0
# Tracking direction backward/top, frame 71
# Tracking direction backward/top, frame 60
# Tracking direction backward/top, frame 48
# Tracking direction forward/bottom, frame 4
# Tracking direction backward/top, frame 72
# Tracking direction forward/bottom, frame 1
# Tracking direction backward/top, frame 61
# Tracking direction backward/top, frame 49
# Tracking direction forward/bottom, frame 5
# Tracking direction backward/top, frame 73
# Tracking direction forward/bottom, frame 2
# Tracking direction backward/top, frame 62
# Tracking direction backward/top, frame 50
# Tracking direction forward/bottom, frame 6
# Tracking direction backward/top, frame 74
# Tracking direction forward/bottom, frame 3
# Tracking direction backward/top, frame 63
# Tracking direction backward/top, frame 51
# Tracking direction forward/bottom, frame 7
# Tracking direction backward/top, frame 75
# Tracking direction backward/top, frame 64
# Tracking direction forward/bottom, frame 4
# Tracking direction backward/top, frame 52
# Tracking direction forward/bottom, frame 8
# Tracking direction backward/top, frame 76
# Tracking direction backward/top, frame 65
# Tracking direction forward/bottom, frame 5
# Tracking direction backward/top, frame 53
# Tracking direction forward/bottom, frame 9
# Tracking direction backward/top, frame 77
# Tracking direction backward/top, frame 66
# Tracking direction forward/bottom, frame 6
# Tracking direction backward/top, frame 54
# Tracking direction forward/bottom, frame 10
# Tracking direction backward/top, frame 67
# Tracking direction backward/top, frame 78
# Tracking direction forward/bottom, frame 7
# Tracking direction backward/top, frame 55
# Tracking direction forward/bottom, frame 11
# Tracking direction backward/top, frame 68
# Tracking direction backward/top, frame 79
# Tracking direction forward/bottom, frame 8
# Tracking direction backward/top, frame 56
# Tracking direction forward/bottom, frame 12
# Tracking direction backward/top, frame 69
# Tracking direction forward/bottom, frame 9
# Tracking direction forward/bottom, frame 0
# Tracking direction backward/top, frame 57
# Tracking direction forward/bottom, frame 13
# Tracking direction backward/top, frame 70
# Tracking direction forward/bottom, frame 10
# Tracking direction forward/bottom, frame 1
# Tracking direction backward/top, frame 58
# Tracking direction forward/bottom, frame 14
# Tracking direction backward/top, frame 71
# Tracking direction forward/bottom, frame 11
# Tracking direction forward/bottom, frame 2
# Tracking direction backward/top, frame 59
# Tracking direction forward/bottom, frame 15
# Tracking direction backward/top, frame 72
# Tracking direction forward/bottom, frame 12
# Tracking direction backward/top, frame 60
# Tracking direction forward/bottom, frame 3
# Tracking direction forward/bottom, frame 16
# Tracking direction backward/top, frame 73
# Tracking direction forward/bottom, frame 13
# Tracking direction backward/top, frame 61
# Tracking direction forward/bottom, frame 4
# Tracking direction forward/bottom, frame 17
# Tracking direction backward/top, frame 74
# Tracking direction forward/bottom, frame 14
# Tracking direction backward/top, frame 62
# Tracking direction forward/bottom, frame 18
# Tracking direction forward/bottom, frame 5
# Tracking direction backward/top, frame 75
# Tracking direction forward/bottom, frame 15
# Tracking direction backward/top, frame 63
# Tracking direction forward/bottom, frame 19
# Tracking direction forward/bottom, frame 6
# Tracking direction backward/top, frame 76
# Tracking direction forward/bottom, frame 16
# Tracking direction backward/top, frame 64
# Tracking direction forward/bottom, frame 20
# Tracking direction forward/bottom, frame 7
# Tracking direction backward/top, frame 77
# Tracking direction forward/bottom, frame 17
# Tracking direction backward/top, frame 65
# Tracking direction forward/bottom, frame 21
# Tracking direction forward/bottom, frame 8
# Tracking direction backward/top, frame 78
# Tracking direction forward/bottom, frame 18
# Tracking direction backward/top, frame 66
# Tracking direction forward/bottom, frame 22
# Tracking direction forward/bottom, frame 9
# Tracking direction backward/top, frame 79
# Tracking direction backward/top, frame 67
# Tracking direction forward/bottom, frame 19
# Tracking direction forward/bottom, frame 10
# Tracking direction forward/bottom, frame 23
# Tracking direction backward/top, frame 68
# Tracking direction forward/bottom, frame 20
# Tracking direction forward/bottom, frame 11
# Tracking direction forward/bottom, frame 0
# Tracking direction forward/bottom, frame 24
# Tracking direction backward/top, frame 69
# Tracking direction forward/bottom, frame 21
# Tracking direction forward/bottom, frame 12
# Tracking direction forward/bottom, frame 1
# Tracking direction forward/bottom, frame 25
# Tracking direction forward/bottom, frame 22
# Tracking direction backward/top, frame 70
# Tracking direction forward/bottom, frame 13
# Tracking direction forward/bottom, frame 26
# Tracking direction forward/bottom, frame 2
# Tracking direction forward/bottom, frame 23
# Tracking direction backward/top, frame 71
# Tracking direction forward/bottom, frame 14
# Tracking direction forward/bottom, frame 3
# Tracking direction forward/bottom, frame 27
# Tracking direction forward/bottom, frame 24
# Tracking direction backward/top, frame 72
# Tracking direction forward/bottom, frame 15
# Tracking direction forward/bottom, frame 28
# Tracking direction forward/bottom, frame 4
# Tracking direction forward/bottom, frame 25
# Tracking direction backward/top, frame 73
# Tracking direction forward/bottom, frame 16
# Tracking direction forward/bottom, frame 5
# Tracking direction forward/bottom, frame 29
# Tracking direction forward/bottom, frame 26
# Tracking direction backward/top, frame 74
# Tracking direction forward/bottom, frame 17
# Tracking direction forward/bottom, frame 6
# Tracking direction forward/bottom, frame 30
# Tracking direction forward/bottom, frame 27
# Tracking direction backward/top, frame 75
# Tracking direction forward/bottom, frame 18
# Tracking direction forward/bottom, frame 7
# Tracking direction forward/bottom, frame 31
# Tracking direction forward/bottom, frame 28
# Tracking direction backward/top, frame 76
# Tracking direction forward/bottom, frame 19
# Tracking direction forward/bottom, frame 32
# Tracking direction forward/bottom, frame 8
# Tracking direction backward/top, frame 77
# Tracking direction forward/bottom, frame 29
# Tracking direction forward/bottom, frame 20
# Tracking direction forward/bottom, frame 9
# Tracking direction forward/bottom, frame 33
# Tracking direction backward/top, frame 78
# Tracking direction forward/bottom, frame 30
# Tracking direction forward/bottom, frame 21
# Tracking direction forward/bottom, frame 34
# Tracking direction forward/bottom, frame 10
# Tracking direction backward/top, frame 79
# Tracking direction forward/bottom, frame 31
# Tracking direction forward/bottom, frame 22
# Tracking direction forward/bottom, frame 35
# Tracking direction forward/bottom, frame 11
# Tracking direction forward/bottom, frame 32
# Tracking direction forward/bottom, frame 23
# Tracking direction forward/bottom, frame 0
# Tracking direction forward/bottom, frame 36
# Tracking direction forward/bottom, frame 12
# Tracking direction forward/bottom, frame 24
# Tracking direction forward/bottom, frame 33
# Tracking direction forward/bottom, frame 1
# Tracking direction forward/bottom, frame 13
# Tracking direction forward/bottom, frame 37
# Tracking direction forward/bottom, frame 25
# Tracking direction forward/bottom, frame 34
# Tracking direction forward/bottom, frame 38
# Tracking direction forward/bottom, frame 14
# Tracking direction forward/bottom, frame 2
# Tracking direction forward/bottom, frame 26
# Tracking direction forward/bottom, frame 35
# Tracking direction forward/bottom, frame 39
# Tracking direction forward/bottom, frame 3
# Tracking direction forward/bottom, frame 15
# Tracking direction forward/bottom, frame 36
# Tracking direction forward/bottom, frame 27
# Tracking direction forward/bottom, frame 4
# Tracking direction forward/bottom, frame 40
# Tracking direction forward/bottom, frame 16
# Tracking direction forward/bottom, frame 37
# Tracking direction forward/bottom, frame 28
# Tracking direction forward/bottom, frame 41
# Tracking direction forward/bottom, frame 5
# Tracking direction forward/bottom, frame 17
# Tracking direction forward/bottom, frame 38
# Tracking direction forward/bottom, frame 29
# Tracking direction forward/bottom, frame 42
# Tracking direction forward/bottom, frame 6
# Tracking direction forward/bottom, frame 18
# Tracking direction forward/bottom, frame 30
# Tracking direction forward/bottom, frame 39
# Tracking direction forward/bottom, frame 43
# Tracking direction forward/bottom, frame 7
# Tracking direction forward/bottom, frame 19
# Tracking direction forward/bottom, frame 40
# Tracking direction forward/bottom, frame 31
# Tracking direction forward/bottom, frame 44
# Tracking direction forward/bottom, frame 8
# Tracking direction forward/bottom, frame 20
# Tracking direction forward/bottom, frame 41
# Tracking direction forward/bottom, frame 32
# Tracking direction forward/bottom, frame 45
# Tracking direction forward/bottom, frame 9
# Tracking direction forward/bottom, frame 21
# Tracking direction forward/bottom, frame 42
# Tracking direction forward/bottom, frame 33
# Tracking direction forward/bottom, frame 46
# Tracking direction forward/bottom, frame 10
# Tracking direction forward/bottom, frame 22
# Tracking direction forward/bottom, frame 34
# Tracking direction forward/bottom, frame 43
# Tracking direction forward/bottom, frame 47
# Tracking direction forward/bottom, frame 11
# Tracking direction forward/bottom, frame 23
# Tracking direction forward/bottom, frame 35
# Tracking direction forward/bottom, frame 44
# Tracking direction forward/bottom, frame 48
# Tracking direction forward/bottom, frame 12
# Tracking direction forward/bottom, frame 24
# Tracking direction forward/bottom, frame 45
# Tracking direction forward/bottom, frame 49
# Tracking direction forward/bottom, frame 36
# Tracking direction forward/bottom, frame 13
# Tracking direction forward/bottom, frame 25
# Tracking direction forward/bottom, frame 46
# Tracking direction forward/bottom, frame 50
# Tracking direction forward/bottom, frame 37
# Tracking direction forward/bottom, frame 14
# Tracking direction forward/bottom, frame 26
# Tracking direction forward/bottom, frame 47
# Tracking direction forward/bottom, frame 51
# Tracking direction forward/bottom, frame 15
# Tracking direction forward/bottom, frame 38
# Tracking direction forward/bottom, frame 27
# Tracking direction forward/bottom, frame 48
# Tracking direction forward/bottom, frame 16
# Tracking direction forward/bottom, frame 52
# Tracking direction forward/bottom, frame 39
# Tracking direction forward/bottom, frame 28
# Tracking direction forward/bottom, frame 49
# Tracking direction forward/bottom, frame 17
# Tracking direction forward/bottom, frame 53
# Tracking direction forward/bottom, frame 40
# Tracking direction forward/bottom, frame 29
# Tracking direction forward/bottom, frame 50
# Tracking direction forward/bottom, frame 18
# Tracking direction forward/bottom, frame 54
# Tracking direction forward/bottom, frame 41
# Tracking direction forward/bottom, frame 30
# Tracking direction forward/bottom, frame 51
# Tracking direction forward/bottom, frame 19
# Tracking direction forward/bottom, frame 55
# Tracking direction forward/bottom, frame 42
# Tracking direction forward/bottom, frame 31
# Tracking direction forward/bottom, frame 52
# Tracking direction forward/bottom, frame 56
# Tracking direction forward/bottom, frame 20
# Tracking direction forward/bottom, frame 43
# Tracking direction forward/bottom, frame 32
# Tracking direction forward/bottom, frame 53
# Tracking direction forward/bottom, frame 57
# Tracking direction forward/bottom, frame 21
# Tracking direction forward/bottom, frame 44
# Tracking direction forward/bottom, frame 33
# Tracking direction forward/bottom, frame 54
# Tracking direction forward/bottom, frame 58
# Tracking direction forward/bottom, frame 22
# Tracking direction forward/bottom, frame 45
# Tracking direction forward/bottom, frame 34
# Tracking direction forward/bottom, frame 55
# Tracking direction forward/bottom, frame 59
# Tracking direction forward/bottom, frame 23
# Tracking direction forward/bottom, frame 46
# Tracking direction forward/bottom, frame 35
# Tracking direction forward/bottom, frame 56
# Tracking direction forward/bottom, frame 60
# Tracking direction forward/bottom, frame 24
# Tracking direction forward/bottom, frame 47
# Tracking direction forward/bottom, frame 36
# Tracking direction forward/bottom, frame 57
# Tracking direction forward/bottom, frame 61
# Tracking direction forward/bottom, frame 25
# Tracking direction forward/bottom, frame 48
# Tracking direction forward/bottom, frame 37
# Tracking direction forward/bottom, frame 58
# Tracking direction forward/bottom, frame 62
# Tracking direction forward/bottom, frame 26
# Tracking direction forward/bottom, frame 49
# Tracking direction forward/bottom, frame 38
# Tracking direction forward/bottom, frame 59
# Tracking direction forward/bottom, frame 63
# Tracking direction forward/bottom, frame 27
# Tracking direction forward/bottom, frame 50
# Tracking direction forward/bottom, frame 39
# Tracking direction forward/bottom, frame 60
# Tracking direction forward/bottom, frame 64
# Tracking direction forward/bottom, frame 28
# Tracking direction forward/bottom, frame 51
# Tracking direction forward/bottom, frame 40
# Tracking direction forward/bottom, frame 61
# Tracking direction forward/bottom, frame 65
# Tracking direction forward/bottom, frame 29
# Tracking direction forward/bottom, frame 52
# Tracking direction forward/bottom, frame 41
# Tracking direction forward/bottom, frame 62
# Tracking direction forward/bottom, frame 66
# Tracking direction forward/bottom, frame 53
# Tracking direction forward/bottom, frame 30
# Tracking direction forward/bottom, frame 42
# Tracking direction forward/bottom, frame 63
# Tracking direction forward/bottom, frame 67
# Tracking direction forward/bottom, frame 54
# Tracking direction forward/bottom, frame 31
# Tracking direction forward/bottom, frame 43
# Tracking direction forward/bottom, frame 64
# Tracking direction forward/bottom, frame 68
# Tracking direction forward/bottom, frame 55
# Tracking direction forward/bottom, frame 32
# Tracking direction forward/bottom, frame 44
# Tracking direction forward/bottom, frame 65
# Tracking direction forward/bottom, frame 69
# Tracking direction forward/bottom, frame 33
# Tracking direction forward/bottom, frame 56
# Tracking direction forward/bottom, frame 45
# Tracking direction forward/bottom, frame 66
# Tracking direction forward/bottom, frame 70
# Tracking direction forward/bottom, frame 34
# Tracking direction forward/bottom, frame 57
# Tracking direction forward/bottom, frame 46
# Tracking direction forward/bottom, frame 67
# Tracking direction forward/bottom, frame 71
# Tracking direction forward/bottom, frame 35
# Tracking direction forward/bottom, frame 58
# Tracking direction forward/bottom, frame 47
# Tracking direction forward/bottom, frame 68
# Tracking direction forward/bottom, frame 59
# Tracking direction forward/bottom, frame 72
# Tracking direction forward/bottom, frame 36
# Tracking direction forward/bottom, frame 48
# Tracking direction forward/bottom, frame 69
# Tracking direction forward/bottom, frame 73
# Tracking direction forward/bottom, frame 60
# Tracking direction forward/bottom, frame 37
# Tracking direction forward/bottom, frame 49
# Tracking direction forward/bottom, frame 70
# Tracking direction forward/bottom, frame 74
# Tracking direction forward/bottom, frame 61
# Tracking direction forward/bottom, frame 38
# Tracking direction forward/bottom, frame 50
# Tracking direction forward/bottom, frame 71
# Tracking direction forward/bottom, frame 62
# Tracking direction forward/bottom, frame 75
# Tracking direction forward/bottom, frame 39
# Tracking direction forward/bottom, frame 51
# Tracking direction forward/bottom, frame 72
# Tracking direction forward/bottom, frame 76
# Tracking direction forward/bottom, frame 63
# Tracking direction forward/bottom, frame 40
# Tracking direction forward/bottom, frame 52
# Tracking direction forward/bottom, frame 73
# Tracking direction forward/bottom, frame 77
# Tracking direction forward/bottom, frame 41
# Tracking direction forward/bottom, frame 64
# Tracking direction forward/bottom, frame 53
# Tracking direction forward/bottom, frame 74
# Tracking direction forward/bottom, frame 42
# Tracking direction forward/bottom, frame 65
# Tracking direction forward/bottom, frame 78
# Tracking direction forward/bottom, frame 54
# Tracking direction forward/bottom, frame 75
# Tracking direction forward/bottom, frame 79
# Tracking direction forward/bottom, frame 43
# Tracking direction forward/bottom, frame 66
# Tracking direction forward/bottom, frame 55
# Tracking direction forward/bottom, frame 76
# Tracking direction forward/bottom, frame 44
# Tracking direction forward/bottom, frame 67
# Tracking direction forward/bottom, frame 56
# Tracking direction backward/bottom, frame 0
# Tracking direction forward/bottom, frame 77
# Tracking direction forward/bottom, frame 45
# Tracking direction forward/bottom, frame 68
# Tracking direction forward/bottom, frame 57
# ...
# Tracking direction forward/bottom, frame 14
# Tracking direction backward/bottom, frame 11
# Tracking direction forward/bottom, frame 55
# Tracking direction backward/bottom, frame 49
# Tracking direction forward/bottom, frame 15
# Tracking direction backward/bottom, frame 12
# Tracking direction forward/bottom, frame 56
# Tracking direction backward/bottom, frame 50
# Tracking direction forward/bottom, frame 16
# Tracking direction backward/bottom, frame 13
# Tracking direction backward/bottom, frame 51
# Tracking direction forward/bottom, frame 57
# Tracking direction forward/bottom, frame 17
# Tracking direction backward/bottom, frame 14
# Tracking direction backward/bottom, frame 52
# Tracking direction forward/bottom, frame 58
# Tracking direction forward/bottom, frame 18
# Tracking direction backward/bottom, frame 15
# Tracking direction backward/bottom, frame 53
# Tracking direction forward/bottom, frame 59
# Tracking direction forward/bottom, frame 19
# Tracking direction backward/bottom, frame 16
# Tracking direction backward/bottom, frame 54
# Tracking direction forward/bottom, frame 60
# Tracking direction forward/bottom, frame 20
# Tracking direction backward/bottom, frame 17
# Tracking direction backward/bottom, frame 55
# Tracking direction forward/bottom, frame 61
# Tracking direction forward/bottom, frame 21
# Tracking direction backward/bottom, frame 18
# Tracking direction backward/bottom, frame 56
# Tracking direction forward/bottom, frame 62
# Tracking direction forward/bottom, frame 22
# Tracking direction backward/bottom, frame 19
# Tracking direction forward/bottom, frame 63
# Tracking direction backward/bottom, frame 57
# Tracking direction forward/bottom, frame 23
# Tracking direction backward/bottom, frame 20
# Tracking direction backward/bottom, frame 58
# Tracking direction forward/bottom, frame 64
# Tracking direction forward/bottom, frame 24
# Tracking direction backward/bottom, frame 59
# Tracking direction backward/bottom, frame 21
# Tracking direction forward/bottom, frame 65
# Tracking direction forward/bottom, frame 25
# Tracking direction backward/bottom, frame 60
# Tracking direction backward/bottom, frame 22
# Tracking direction forward/bottom, frame 66
# Tracking direction forward/bottom, frame 26
# Tracking direction backward/bottom, frame 23
# Tracking direction backward/bottom, frame 61
# Tracking direction forward/bottom, frame 67
# Tracking direction forward/bottom, frame 27
# Tracking direction backward/bottom, frame 24
# Tracking direction backward/bottom, frame 62
# Tracking direction forward/bottom, frame 68
# Tracking direction forward/bottom, frame 28
# Tracking direction backward/bottom, frame 63
# Tracking direction backward/bottom, frame 25
# Tracking direction forward/bottom, frame 69
# Tracking direction forward/bottom, frame 29
# Tracking direction backward/bottom, frame 64
# Tracking direction backward/bottom, frame 26
# Tracking direction forward/bottom, frame 70
# Tracking direction forward/bottom, frame 30
# Tracking direction backward/bottom, frame 27
# Tracking direction backward/bottom, frame 65
# Tracking direction forward/bottom, frame 71
# Tracking direction forward/bottom, frame 31
# Tracking direction backward/bottom, frame 28
# Tracking direction backward/bottom, frame 66
# Tracking direction forward/bottom, frame 72
# Tracking direction forward/bottom, frame 32
# Tracking direction backward/bottom, frame 29
# Tracking direction backward/bottom, frame 67
# Tracking direction forward/bottom, frame 73
# Tracking direction forward/bottom, frame 33
# Tracking direction backward/bottom, frame 30
# Tracking direction backward/bottom, frame 68
# Tracking direction forward/bottom, frame 74
# Tracking direction forward/bottom, frame 34
# Tracking direction backward/bottom, frame 31
# Tracking direction backward/bottom, frame 69
# Tracking direction forward/bottom, frame 75
# Tracking direction forward/bottom, frame 35
# Tracking direction backward/bottom, frame 32
# Tracking direction backward/bottom, frame 70
# Tracking direction forward/bottom, frame 76
# Tracking direction forward/bottom, frame 36
# Tracking direction backward/bottom, frame 33
# Tracking direction backward/bottom, frame 71
# Tracking direction forward/bottom, frame 77
# Tracking direction forward/bottom, frame 37
# Tracking direction backward/bottom, frame 72
# Tracking direction backward/bottom, frame 34
# Tracking direction forward/bottom, frame 78
# Tracking direction forward/bottom, frame 38
# Tracking direction backward/bottom, frame 73
# Tracking direction backward/bottom, frame 35
# Tracking direction forward/bottom, frame 79
# Tracking direction forward/bottom, frame 39
# Tracking direction backward/bottom, frame 36
# Tracking direction backward/bottom, frame 74
# Tracking direction backward/bottom, frame 0
# Tracking direction forward/bottom, frame 40
# Tracking direction backward/bottom, frame 37
# Tracking direction backward/bottom, frame 75
# Tracking direction backward/bottom, frame 1
# Tracking direction forward/bottom, frame 41
# Tracking direction backward/bottom, frame 38
# Tracking direction backward/bottom, frame 76
# Tracking direction backward/bottom, frame 2
# Tracking direction forward/bottom, frame 42
# Tracking direction backward/bottom, frame 39
# Tracking direction backward/bottom, frame 77
# Tracking direction forward/bottom, frame 43
# Tracking direction backward/bottom, frame 3
# Tracking direction backward/bottom, frame 40
# Tracking direction backward/bottom, frame 78
# Tracking direction forward/bottom, frame 44
# Tracking direction backward/bottom, frame 4
# Tracking direction backward/bottom, frame 79
# Tracking direction backward/bottom, frame 41
# Tracking direction forward/bottom, frame 45
# Tracking direction backward/bottom, frame 5
# Tracking direction backward/bottom, frame 42
# Tracking direction forward/bottom, frame 46
# Tracking direction backward/bottom, frame 6
# Tracking direction backward/bottom, frame 43
# Tracking direction forward/bottom, frame 47
# Tracking direction backward/bottom, frame 44
# Tracking direction backward/bottom, frame 7
# Tracking direction forward/bottom, frame 48
# Tracking direction backward/bottom, frame 8
# Tracking direction backward/bottom, frame 45
# Tracking direction forward/bottom, frame 49
# Tracking direction backward/bottom, frame 9
# Tracking direction backward/bottom, frame 46
# Tracking direction forward/bottom, frame 50
# Tracking direction backward/bottom, frame 10
# Tracking direction backward/bottom, frame 47
# Tracking direction forward/bottom, frame 51
# Tracking direction backward/bottom, frame 11
# Tracking direction backward/bottom, frame 48
# Tracking direction forward/bottom, frame 52
# Tracking direction backward/bottom, frame 12
# Tracking direction backward/bottom, frame 49
# Tracking direction forward/bottom, frame 53
# Tracking direction backward/bottom, frame 13
# Tracking direction backward/bottom, frame 50
# Tracking direction forward/bottom, frame 54
# Tracking direction backward/bottom, frame 14
# Tracking direction backward/bottom, frame 51
# Tracking direction forward/bottom, frame 55
# Tracking direction backward/bottom, frame 15
# Tracking direction backward/bottom, frame 52
# Tracking direction forward/bottom, frame 56
# Tracking direction backward/bottom, frame 16
# Tracking direction backward/bottom, frame 53
# Tracking direction forward/bottom, frame 57
# Tracking direction backward/bottom, frame 17
# Tracking direction backward/bottom, frame 54
# Tracking direction forward/bottom, frame 58
# Tracking direction backward/bottom, frame 18
# Tracking direction backward/bottom, frame 55
# Tracking direction forward/bottom, frame 59
# Tracking direction backward/bottom, frame 19
# Tracking direction backward/bottom, frame 56
# Tracking direction forward/bottom, frame 60
# Tracking direction backward/bottom, frame 20
# Tracking direction backward/bottom, frame 57
# Tracking direction forward/bottom, frame 61
# Tracking direction backward/bottom, frame 21
# Tracking direction backward/bottom, frame 58
# Tracking direction forward/bottom, frame 62
# Tracking direction backward/bottom, frame 22
# Tracking direction backward/bottom, frame 59
# Tracking direction forward/bottom, frame 63
# Tracking direction backward/bottom, frame 23
# Tracking direction backward/bottom, frame 60
# Tracking direction forward/bottom, frame 64
# Tracking direction backward/bottom, frame 24
# Tracking direction backward/bottom, frame 61
# Tracking direction forward/bottom, frame 65
# Tracking direction backward/bottom, frame 62
# Tracking direction backward/bottom, frame 25
# Tracking direction forward/bottom, frame 66
# Tracking direction backward/bottom, frame 26
# Tracking direction backward/bottom, frame 63
# Tracking direction forward/bottom, frame 67
# Tracking direction backward/bottom, frame 64
# Tracking direction backward/bottom, frame 27
# Tracking direction forward/bottom, frame 68
# Tracking direction backward/bottom, frame 65
# Tracking direction backward/bottom, frame 28
# Tracking direction forward/bottom, frame 69
# Tracking direction backward/bottom, frame 66
# Tracking direction backward/bottom, frame 29
# Tracking direction forward/bottom, frame 70
# Tracking direction backward/bottom, frame 67
# Tracking direction backward/bottom, frame 30
# Tracking direction forward/bottom, frame 71
# Tracking direction backward/bottom, frame 31
# Tracking direction backward/bottom, frame 68
# Tracking direction forward/bottom, frame 72
# Tracking direction backward/bottom, frame 69
# Tracking direction backward/bottom, frame 32
# Tracking direction forward/bottom, frame 73
# Tracking direction backward/bottom, frame 70
# Tracking direction backward/bottom, frame 33
# Tracking direction forward/bottom, frame 74
# Tracking direction backward/bottom, frame 34
# Tracking direction backward/bottom, frame 71
# Tracking direction forward/bottom, frame 75
# Tracking direction backward/bottom, frame 72
# Tracking direction backward/bottom, frame 35
# Tracking direction forward/bottom, frame 76
# Tracking direction backward/bottom, frame 73
# Tracking direction backward/bottom, frame 36
# Tracking direction forward/bottom, frame 77
# Tracking direction backward/bottom, frame 37
# Tracking direction backward/bottom, frame 74
# Tracking direction forward/bottom, frame 78
# Tracking direction backward/bottom, frame 75
# Tracking direction backward/bottom, frame 38
# Tracking direction forward/bottom, frame 79
# Tracking direction backward/bottom, frame 76
# Tracking direction backward/bottom, frame 39
# Tracking direction backward/bottom, frame 77
# Tracking direction backward/bottom, frame 40
# Tracking direction backward/bottom, frame 0
# Tracking direction backward/bottom, frame 41
# Tracking direction backward/bottom, frame 78
# Tracking direction backward/bottom, frame 1
# Tracking direction backward/bottom, frame 42
# Tracking direction backward/bottom, frame 79
# Tracking direction backward/bottom, frame 2
# Tracking direction backward/bottom, frame 43
# Tracking direction backward/bottom, frame 3
# Tracking direction backward/bottom, frame 44
# Tracking direction backward/bottom, frame 4
# Tracking direction backward/bottom, frame 45
# Tracking direction backward/bottom, frame 5
# Tracking direction backward/bottom, frame 46
# Tracking direction backward/bottom, frame 6
# Tracking direction backward/bottom, frame 47
# Tracking direction backward/bottom, frame 7
# Tracking direction backward/bottom, frame 48
# Tracking direction backward/bottom, frame 8
# Tracking direction backward/bottom, frame 49
# Tracking direction backward/bottom, frame 9
# Tracking direction backward/bottom, frame 50
# Tracking direction backward/bottom, frame 10
# Tracking direction backward/bottom, frame 51
# Tracking direction backward/bottom, frame 11
# Tracking direction backward/bottom, frame 52
# Tracking direction backward/bottom, frame 12
# Tracking direction backward/bottom, frame 53
# Tracking direction backward/bottom, frame 13
# Tracking direction backward/bottom, frame 54
# Tracking direction backward/bottom, frame 14
# Tracking direction backward/bottom, frame 55
# Tracking direction backward/bottom, frame 15
# Tracking direction backward/bottom, frame 56
# Tracking direction backward/bottom, frame 16
# Tracking direction backward/bottom, frame 57
# Tracking direction backward/bottom, frame 17
# Tracking direction backward/bottom, frame 58
# Tracking direction backward/bottom, frame 18
# Tracking direction backward/bottom, frame 59
# Tracking direction backward/bottom, frame 19
# Tracking direction backward/bottom, frame 60
# Tracking direction backward/bottom, frame 20
# Tracking direction backward/bottom, frame 61
# Tracking direction backward/bottom, frame 21
# Tracking direction backward/bottom, frame 62
# Tracking direction backward/bottom, frame 22
# Tracking direction backward/bottom, frame 63
# Tracking direction backward/bottom, frame 23
# Tracking direction backward/bottom, frame 64
# Tracking direction backward/bottom, frame 24
# Tracking direction backward/bottom, frame 65
# Tracking direction backward/bottom, frame 25
# Tracking direction backward/bottom, frame 66
# Tracking direction backward/bottom, frame 26
# Tracking direction backward/bottom, frame 67
# Tracking direction backward/bottom, frame 27
# Tracking direction backward/bottom, frame 68
# Tracking direction backward/bottom, frame 28
# Tracking direction backward/bottom, frame 69
# Tracking direction backward/bottom, frame 29
# Tracking direction backward/bottom, frame 70
# Tracking direction backward/bottom, frame 30
# Tracking direction backward/bottom, frame 71
# Tracking direction backward/bottom, frame 31
# Tracking direction backward/bottom, frame 72
# Tracking direction backward/bottom, frame 32
# Tracking direction backward/bottom, frame 73
# Tracking direction backward/bottom, frame 33
# Tracking direction backward/bottom, frame 74
# Tracking direction backward/bottom, frame 34
# Tracking direction backward/bottom, frame 75
# Tracking direction backward/bottom, frame 35
# Tracking direction backward/bottom, frame 76
# Tracking direction backward/bottom, frame 36
# Tracking direction backward/bottom, frame 77
# Tracking direction backward/bottom, frame 37
# Tracking direction backward/bottom, frame 78
# Tracking direction backward/bottom, frame 38
# Tracking direction backward/bottom, frame 79
# Tracking direction backward/bottom, frame 39
# Tracking direction backward/bottom, frame 40
# Tracking direction backward/bottom, frame 41
# Tracking direction backward/bottom, frame 42
# Tracking direction backward/bottom, frame 43
# Tracking direction backward/bottom, frame 44
# Tracking direction backward/bottom, frame 45
# Tracking direction backward/bottom, frame 46
# Tracking direction backward/bottom, frame 47
# Tracking direction backward/bottom, frame 48
# Tracking direction backward/bottom, frame 49
# Tracking direction backward/bottom, frame 50
# Tracking direction backward/bottom, frame 51
# Tracking direction backward/bottom, frame 52
# Tracking direction backward/bottom, frame 53
# Tracking direction backward/bottom, frame 54
# Tracking direction backward/bottom, frame 55
# Tracking direction backward/bottom, frame 56
# Tracking direction backward/bottom, frame 57
# Tracking direction backward/bottom, frame 58
# Tracking direction backward/bottom, frame 59
# Tracking direction backward/bottom, frame 60
# Tracking direction backward/bottom, frame 61
# Tracking direction backward/bottom, frame 62
# Tracking direction backward/bottom, frame 63
# Tracking direction backward/bottom, frame 64
# Tracking direction backward/bottom, frame 65
# Tracking direction backward/bottom, frame 66
# Tracking direction backward/bottom, frame 67
# Tracking direction backward/bottom, frame 68
# Tracking direction backward/bottom, frame 69
# Tracking direction backward/bottom, frame 70
# Tracking direction backward/bottom, frame 71
# Tracking direction backward/bottom, frame 72
# Tracking direction backward/bottom, frame 73
# Tracking direction backward/bottom, frame 74
# Tracking direction backward/bottom, frame 75
# Tracking direction backward/bottom, frame 76
# Tracking direction backward/bottom, frame 77
# Tracking direction backward/bottom, frame 78
# Tracking direction backward/bottom, frame 79
# saving ballpos_top_list.npy and ballbpos_bottom_list.npy...
# saved ballpos_top_list.npy in /Users/rattie/Data/Ben/SteinSDO/calibration/
# saved ballpos_bottom_list.npy in /Users/rattie/Data/Ben/SteinSDO/calibration/
# duration_time_clock:    4.7611300000000085
# a_avg = 1.00, p[1] = -0.00

# %%
# Benoit FLCT data directory. 1 directory per drift value -> 9 directories for 9 drift values
data_dir = '/Users/rattie/Data/Ben/SteinSDO/calibration/FLCT_Benoit/FLCT_drift_filt_non_norm/output_flct_sigma7'
fvx_files = [os.path.join(data_dir, 'drift_filt_non_norm_{:d}'.format(i), 'FLCT_vx1_000-079.fits') for i in range(9)]
fvx_files
# Out:
# ['/Users/rattie/Data/Ben/SteinSDO/calibration/FLCT_Benoit/FLCT_drift_filt_non_norm/output_flct_sigma7/drift_filt_non_norm_0/FLCT_vx1_000-079.fits',
#  '/Users/rattie/Data/Ben/SteinSDO/calibration/FLCT_Benoit/FLCT_drift_filt_non_norm/output_flct_sigma7/drift_filt_non_norm_1/FLCT_vx1_000-079.fits',
#  '/Users/rattie/Data/Ben/SteinSDO/calibration/FLCT_Benoit/FLCT_drift_filt_non_norm/output_flct_sigma7/drift_filt_non_norm_2/FLCT_vx1_000-079.fits',
#  '/Users/rattie/Data/Ben/SteinSDO/calibration/FLCT_Benoit/FLCT_drift_filt_non_norm/output_flct_sigma7/drift_filt_non_norm_3/FLCT_vx1_000-079.fits',
#  '/Users/rattie/Data/Ben/SteinSDO/calibration/FLCT_Benoit/FLCT_drift_filt_non_norm/output_flct_sigma7/drift_filt_non_norm_4/FLCT_vx1_000-079.fits',
#  '/Users/rattie/Data/Ben/SteinSDO/calibration/FLCT_Benoit/FLCT_drift_filt_non_norm/output_flct_sigma7/drift_filt_non_norm_5/FLCT_vx1_000-079.fits',
#  '/Users/rattie/Data/Ben/SteinSDO/calibration/FLCT_Benoit/FLCT_drift_filt_non_norm/output_flct_sigma7/drift_filt_non_norm_6/FLCT_vx1_000-079.fits',
#  '/Users/rattie/Data/Ben/SteinSDO/calibration/FLCT_Benoit/FLCT_drift_filt_non_norm/output_flct_sigma7/drift_filt_non_norm_7/FLCT_vx1_000-079.fits',
#  '/Users/rattie/Data/Ben/SteinSDO/calibration/FLCT_Benoit/FLCT_drift_filt_non_norm/output_flct_sigma7/drift_filt_non_norm_8/FLCT_vx1_000-079.fits']

# %%
# Loop through Benoit's matrix data
fvxmeans, a_fv, fvxfits, fv_residuals0, fv_residuals = dv_analysis(fvx_files, vx_ratesu, fov_slices)

# %%
# Setup some figure parameters
label = 'FLCT'
# Default plot params
fs = 12
plt.rcParams.update({'font.size': fs})
markers = 'd'
colors = 'red'
legend_loc = 'lower right'
# Widths of bar plots
widths = [0.015, 0.015, 0.01]
# Plot figure file name suffix
fig_suffix = 'intsteps_{:d}_dp_{:0.2f}_sigma_factor_{:0.2f}'.format(intsteps, dp, sigma_factor)
dpi = 300

# %%
    maxv = 0.3 * unit

    # %matplotlib notebook
    fig, axs = plt.subplots(nrows = 1, ncols = 1, figsize=(7, 7))
    axs.set_title('FWHM = 7 px')
    # Consider only the unfiltered ones (the filtered ones do not work). range from 0 to 5 incl.
    axs.plot(fvxmeans, vx_ratesu, marker=markers, color=colors, ls='none', label=label)
    axs.plot(fvxmeans, fvxfits, color=colors, label=r'$\alpha_{:s}$ ={:0.2f}'.format('D', a_fv))

    axs.plot(vxmeans_bt1 * unit, vx_ratesu, marker='o', markerfacecolor='none', ls='none', color='green', label='Balltracking data')
    axs.plot(vxfit_avg1 * unit, vx_ratesu, ls='-.', color='green', label=r'$\alpha_B = {:0.2f}$'.format(a_avg1))

    axs.axis([-maxv, maxv, -maxv, maxv])
    axs.set_xlabel('Measured velocity {:s}'.format(unit_str), fontsize=fs)
    axs.set_ylabel('True velocity {:s}'.format(unit_str), fontsize=fs)
    axs.legend(loc=legend_loc)
    axs.grid(True)
    axs.set_aspect('equal')

    plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="700">

# %% [markdown]
# ### Show uncorrected and corrected residuals

# %%
######################################
##### Residuals with linear correction
######################################

max_resid1 = 500#0.1 * unit

fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(7, 10))
axs[0].set_title('FWHM = 7 px')
axs[0].set_xlabel('True velocity {:s}'.format(unit_str))
axs[0].set_ylabel('Residuals {:s}'.format(unit_str))
bar_labels = ['{:0.0f}'.format(vxrate) for vxrate in vx_ratesu]
colors = ['red']

axs[0].bar(vx_ratesu, fv_residuals0, width=widths[0] * unit, color=colors[0], tick_label=bar_labels, label='FLCT')
axs[0].bar(vx_ratesu, bt_residuals1 * unit, width=widths[0]*0.7 * unit, color='green', tick_label=None, label='balltracking')
axs[0].set_yscale('log')
axs[0].set_ylim([0.1, max_resid1])
axs[0].legend()
axs[0].grid(True)


######################################
##### Residuals with linear correction
######################################
max_resid2 = 50 #0.01 * unit / 2

axs[1].set_title('FWHM = 7 px (linearly corrected)')
axs[1].set_xlabel('True velocity {:s}'.format(unit_str))
axs[1].set_ylabel('Residuals {:s}'.format(unit_str))
bar_labels = ['{:0.0f}'.format(vxrate) for vxrate in vx_ratesu]
colors = ['black', 'red', 'blue']

axs[1].bar(vx_ratesu, fv_residuals,width=widths[0] * unit, color=colors[0], tick_label=bar_labels, label='FLCT')
axs[1].bar(vx_ratesu, bt_residuals1 * unit, width=widths[0] * 0.7 * unit, color='green', tick_label=bar_labels,label='balltracking')

axs[1].set_yscale('log')
axs[1].set_ylim([0.1, max_resid1])
axs[1].legend()
axs[1].grid(True, axis='y')


plt.tight_layout()

#plt.savefig(os.path.join(outputdir, 'Benoit_FLCT_residuals_{:s}.png'.format(fig_suffix)), dpi=dpi)
# Out:
# <img src="data:image/png;base64,..." width="700">

# %% [markdown]
# ## Note: need to add more samples for the drift rates
